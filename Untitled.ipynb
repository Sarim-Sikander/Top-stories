# %%
#libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from nltk.corpus import stopwords
from nltk import text
import textblob
from textblob import TextBlob
from nltk.stem import PorterStemmer,WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer
from nltk import word_tokenize
import plotly
from plotly import offline
from plotly.offline import iplot
import cufflinks
import re
import string
stop=stopwords.words('English')
import wordcloud
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import numpy as np
# %matplotlib inline
offline.init_notebook_mode(connected=True)
import warnings
warnings.filterwarnings('ignore')
stem=PorterStemmer()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import os

# %%
names=[]

# %%
mypath='C:\\Users\\huzaifamawahab\\Desktop\\Courses\\Data Science Projects\\!Data_Science_Bahria_project\\ShortStories\\'
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
files_obj=[0 for i in range(50)]

# %%
for i in range(50):
    with open(mypath+str(i+1)+".txt",mode='r',encoding='utf-8') as file:
        files_obj[i]=file.read()
        file.close()

# %%
contractions = {
"ain't": "am not",
"aren't": "are not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he would",
"he'd've": "he would have",
"he'll": "he will",
"he'll've": "he will have",
"he's": "he is",
"how'd": "how did",
"how'd'y": "how do you",
"how'll": "how will",
"how's": "how does",
"i'd": "i would",
"i'd've": "i would have",
"i'll": "i will",
"i'll've": "i will have",
"i'm": "i am",
"i've": "i have",
"isn't": "is not",
"it'd": "it would",
"it'd've": "it would have",
"it'll": "it will",
"it'll've": "it will have",
"it's": "it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she would",
"she'd've": "she would have",
"she'll": "she will",
"she'll've": "she will have",
"she's": "she is",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so is",
"that'd": "that would",
"that'd've": "that would have",
"that's": "that is",
"there'd": "there would",
"there'd've": "there would have",
"there's": "there is",
"they'd": "they would",
"they'd've": "they would have",
"they'll": "they will",
"they'll've": "they will have",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
"u": "you",
"ur ": "your",
"n": "and"}

# %%
def prep(text):
    text=text.lower()
    text=re.sub('[\\n\\t]','',text)
    text=re.sub('https*\S+','',text)
    text=re.sub('@\S+','',text)
    rem=str(re.escape(string.punctuation))
    text=re.sub('['+rem+']','',text)
    text=[word for word in text.split(' ') if word not in stop]
    for index,value in enumerate(text):
        for key in contractions.keys():
            if(value == key):
                text[index] = contractions[key]
    text=' '.join(text)
    return text

# %%
prep_file=files_obj.copy()

# %%
for index,file in enumerate(files_obj):
    prep_file[index]=prep(file)

# %%
def wordcloud(text):
    
    alice_mask = np.array(Image.open("abcd.jpeg"))
    wc= WordCloud(background_color="white",max_words=4000,mask=alice_mask)

    wc.generate(text)

    plt.figure(figsize=(25,25))
    plt.subplot(221)
    plt.axis("off")
    plt.title("Words frequented", fontsize=20)
    plt.imshow(wc.recolor(colormap= 'gist_earth' , random_state=244), alpha=0.98)
    plt.axis('off')
    plt.show()

# %%
wordcloud(prep_file[1])

# %%
def top_words(text, i):
    vec = CountVectorizer()
    vec.fit(text)
    bow = vec.transform(text)
    wordsum = bow.sum(axis=0)
    words_frequencies = [(words, wordsum[0,index])for words, index in vec.vocabulary_.items()] 
    words_frequencies = sorted(words_frequencies, key=lambda x:x[1], reverse=True)
    return words_frequencies[:i]

def top_words_perpage(text, i):
    vec = CountVectorizer()
    vec.fit([text])
    bow = vec.transform([text])
    wordsum = bow.sum(axis=0)
    words_frequencies = [(words, wordsum[0,index])for words, index in vec.vocabulary_.items()] 
    words_frequencies = sorted(words_frequencies, key=lambda x:x[1], reverse=True)
    return words_frequencies[:i]

# %%
top_word=top_words(prep_file, 10)

# %%
text = pd.DataFrame(top_word,columns=['Word','Freq'])

# %%
text['Word']=text['Word'].str.upper()

# %%
plt.figure(figsize=(15,15))
plt.title("WORD COUNT FOR ALL DOCUMENTS",fontsize=18)
sns.barplot(y=text['Word'],x=text['Freq'])
plt.ylabel('WORD',fontsize=20)
plt.xlabel('FREQUENCY',fontsize=20)
plt.yticks(fontsize=18)
plt.xticks(fontsize=18)
plt.show()

# %%
def top_words(text, i):
    vec = CountVectorizer(ngram_range=(2,2))
    vec.fit(text)
    bow = vec.transform(text)
    wordsum = bow.sum(axis=0)
    words_frequencies = [(words, wordsum[0,index])for words, index in vec.vocabulary_.items()] 
    words_frequencies = sorted(words_frequencies, key=lambda x:x[1], reverse=True)
    return words_frequencies[:i]

# %%
top_words(prep_file, 20)
# Out:
# [('andrey yefimitch', 104),
#  ('ivan dmitritch', 53),
#  ('old man', 49),
#  ('young man', 38),
#  ('mihail averyanitch', 34),
#  ('let us', 28),
#  ('go away', 25),
#  ('don know', 25),
#  ('dear fellow', 22),
#  ('long time', 20),
#  ('let go', 18),
#  ('nina ivanovna', 18),
#  ('don understand', 17),
#  ('far away', 17),
#  ('examining magistrate', 17),
#  ('said andrey', 16),
#  ('pavel vassilyevitch', 16),
#  ('old woman', 15),
#  ('one would', 15),
#  ('yes yes', 15)]

# %%
def top_words(text, i):
    vec = CountVectorizer(ngram_range=(3,3))
    vec.fit(text)
    bow = vec.transform(text)
    wordsum = bow.sum(axis=0)
    words_frequencies = [(words, wordsum[0,index])for words, index in vec.vocabulary_.items()] 
    words_frequencies = sorted(words_frequencies, key=lambda x:x[1], reverse=True)
    return words_frequencies[:i]

# %%
top_words(prep_file, 20)
# Out:
# [('said andrey yefimitch', 13),
#  ('let us go', 13),
#  ('the examining magistrate', 8),
#  ('andrey yefimitch would', 7),
#  ('said ivan dmitritch', 7),
#  ('says young man', 6),
#  ('mihail averyanitch would', 5),
#  ('first time life', 5),
#  ('far far away', 5),
#  ('the young man', 5),
#  ('half hour later', 5),
#  ('mother nina ivanovna', 5),
#  ('twenty years ago', 4),
#  ('mercy upon us', 4),
#  ('five hundred roubles', 4),
#  ('my dear fellow', 4),
#  ('well thank god', 4),
#  ('variegated young ladies', 4),
#  ('little old man', 4),
#  ('says marya petrovna', 4)]

# %%
pp = TextBlob(str(prep_file[0]))

# %%
pp
# Out:
# TextBlob("horsestealersa hospital assistant called yergunov emptyheaded fellow knownthroughout district great braggart drunkard returningone evening christmas week hamlet ryepino hadbeen make purchases hospital might get home ingood time late doctor lent best horseat first still day eight o’clock violent snowstorm came four miles home yergunovcompletely lost wayhe know drive know road drove onat random hoping horse would find way two hourspassed horse exhausted chilled alreadybegan fancy going home back towards ryepino butat last uproar storm heard faraway barking adog murky red blur came sight ahead little bylittle outlines high gate could discerned longfence nails points uppermost beyondthe fence stood slanting crane well wind drove awaythe mist snow eyes redblur sprang small squat little house steep thatchedroof three little windows one covered inside withsomething red lighted upwhat sort place yergunov remembered right theroad three half four miles hospital andreytchirikov’s tavern remembered tchirikov hadbeen lately killed sledgedrivers left wife adaughter called lyubka come hospital two years asa patient inn bad reputation visit late theevening especially someone else’s horse free fromrisk help yergunov fumbled knapsack forhis revolver coughing sternly tapped windowframe hiswhip“hey within” cried “hey granny let come getwarm”with hoarse bark black dog rolled like ball horse’sfeet another white one another black one—there must havebeen dozen yergunov looked see biggestswung whip lashed might small longleggedpuppy turned sharp muzzle upwards set shrill piercinghowlyergunov stood long window tapping last thehoarfrost trees near house glowed red muffled femalefigure appeared lantern hands“let get warm granny” said yergunov “i driving thehospital lost way it’s weather god preserve usdon’t afraid people granny”“all people home didn’t invite strangers” saidthe figure grimly “and knocking gate notlocked”yergunov drove yard stopped steps“bid labourer take horse granny” said he“i granny”and indeed granny putting lanternthe light fell face yergunov saw black eyebrows andrecognized lyubka“there labourers now” said went house“some drunk asleep gone ryepino since themorning it’s holiday   ”as fastened horse shed yergunov heard neigh anddistinguished darkness another horse felt cossacksaddle must someone else house besides woman andher daughter greater security yergunov unsaddled horse andwhen went house took purchases hissaddlethe first room went large hot smelt offreshly washed floors short lean peasant forty asmall fair beard wearing dark blue shirt sitting tableunder holy images kalashnikov arrant scoundrel andhorsestealer whose father uncle kept tavern bogalyovka anddisposed stolen horses could thehospital medical treatment see thedoctor horses—to ask whether one sale whetherhis honour would like swop bay mare duncolouredgelding head pomaded silver earring glittered hisear altogether holiday air frowning dropping hislower lip looking intently big dog’seared picturebookanother peasant lay stretched floor near stove head hisshoulders chest covered sheepskin—he probablyasleep beside new boots shining bits metal heelsthere two dark pools melted snowseeing hospital assistant kalashnikov greeted him“yes weather” said yergunov rubbing chilled knees hisopen hands “the snow one’s neck soaked skin ican tell believe revolver   ”he took revolver looked put back hisknapsack revolver made impression peasant wenton looking book“yes weather    lost way thedogs believe would death would havebeen nice todo women”“the old woman gone ryepino girl getting supper ready  ” answered kalashnikovsilence followed yergunov shivering gasping breathed hishands huddled made show cold exhausted thestill angry dogs could heard howling outside dreary“you come bogalyovka don’t you” asked peasant sternly“yes bogalyovka”and away time yergunov began think bogalyovka itwas big village lay deep ravine one drovealong highroad moonlight night looked darkravine sky seemed  ...

# %%
nltk.download('averaged_perceptron_tagger')
df = pd.DataFrame(pp.pos_tags, columns=['words', 'pos'])
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\huzaifamawahab\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
df_words = df['pos'].value_counts()

# %%
df_words.loc["NN":"DT"].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
def getPolarity(text):
    r=TextBlob(text).sentiment.polarity
    if(r<0):
        return "Negative"
    elif(r==0):
        return "Neutral"
    else:
        return "Positive"
def avg_word_len(text):
    a=text.split(" ")
    sums=0
    for i in a:
        sums=sums+len(i)
    return sums/len(a)

# %%
polarity=[]
for l in prep_file:
    polarity.append(getPolarity(l))
word_count=[]
for k in prep_file:
    word_count.append(len(k))
avg_word=[]
for j in prep_file:
    avg_word.append(avg_word_len(j))

# %%
## ISKO KARNA HAY
data={"names":names_file,"polarity":polarity,'WordCount':word_count,'AVG WORD COUNT: ': avg_word}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-876305735605> in <module>
#       1 ## ISKO KARNA HAY
# ----> 2 data={"names":names_file,"polarity":polarity,'WordCount':word_count,'AVG WORD COUNT: ': avg_word}
#
# NameError: name 'names_file' is not defined

# %%
def stem_(text):
    text=text.split(' ')
    text=[stem.stem(word) for word in text]
    return ' '.join(text)

# %%
stem_files=prep_file.copy()

# %%
for index,v in enumerate(stem_files):
    stem_files[index]=stem_(prep_file[index])

# %%
tokens = ['.',',',';',':','"','``','\'']
wordnet = WordNetLemmatizer()

# %%
for index,v in enumerate(stem_files):
    stem_files[index]=lemmitize(stem_files[index])

# %%
for i in range(50):
    stem_files[i]=wordnet.lemmatize(stem_files[i])

# %%
len(stem_files)
# Out:
# 50

# %%
tfid=TfidfVectorizer()

# %%
query = 'fellow'
tfid.fit_transform(stem_files+[''])
# Out:
# <51x13581 sparse matrix of type '<class 'numpy.float64'>'
# 	with 34585 stored elements in Compressed Sparse Row format>

# %%
tfid.vocabulary_.items()
# Out:
# dict_items([('fellow', 3909), ('horsestealersa', 5470), ('hospit', 5475), ('assist', 1148), ('call', 2022), ('yergunov', 13425), ('emptyhead', 3493), ('knownthroughout', 6339), ('district', 3149), ('great', 4659), ('braggart', 1810), ('drunkard', 3334), ('returningon', 9257), ('even', 3595), ('christma', 2243), ('week', 12889), ('hamlet', 4832), ('ryepino', 9397), ('hadbeen', 4767), ('make', 6825), ('purchas', 8930), ('might', 7085), ('get', 4451), ('home', 5420), ('ingood', 5818), ('time', 11833), ('late', 6437), ('doctor', 3177), ('lent', 6507), ('best', 1614), ('horseat', 5464), ('first', 4015), ('still', 10536), ('day', 2805), ('eight', 3440), ('clock', 2312), ('violent', 12636), ('snowstorm', 10174), ('came', 2034), ('four', 4228), ('mile', 7096), ('yergunovcomplet', 13427), ('lost', 6713), ('wayh', 12859), ('know', 6331), ('drive', 3305), ('road', 9313), ('drove', 3324), ('onat', 7975), ('random', 9017), ('hope', 5449), ('hors', 5460), ('would', 13329), ('find', 3991), ('way', 12856), ('two', 12275), ('hourspass', 5498), ('exhaust', 3683), ('chill', 2222), ('alreadybegan', 412), ('fanci', 3822), ('go', 4514), ('back', 1322), ('toward', 12078), ('butat', 1946), ('last', 6429), ('uproar', 12475), ('storm', 10577), ('heard', 4993), ('faraway', 3829), ('bark', 1371), ('adog', 178), ('murki', 7329), ('red', 9116), ('blur', 1725), ('sight', 9952), ('ahead', 289), ('littl', 6598), ('bylittl', 1996), ('outlin', 8195), ('high', 5204), ('gate', 4394), ('could', 2606), ('discern', 3075), ('longfenc', 6670), ('nail', 7424), ('point', 8641), ('uppermost', 12473), ('beyondth', 1641), ('fenc', 3935), ('stood', 10563), ('slant', 10054), ('crane', 2657), ('well', 12905), ('wind', 13154), ('awayth', 1296), ('mist', 7148), ('snow', 10166), ('eye', 3740), ('redblur', 9119), ('sprang', 10415), ('small', 10104), ('squat', 10430), ('hous', 5499), ('steep', 10507), ('thatchedroof', 11036), ('three', 11777), ('window', 13156), ('one', 7988), ('cover', 2644), ('insid', 5877), ('withsometh', 13244), ('light', 6543), ('upwhat', 12487), ('sort', 10304), ('place', 8592), ('rememb', 9183), ('right', 9291), ('theroad', 11477), ('half', 4815), ('andreytchirikov', 711), ('tavern', 10933), ('tchirikov', 10938), ('kill', 6278), ('sledgedriv', 10061), ('left', 6496), ('wife', 13123), ('adaught', 148), ('lyubka', 6777), ('come', 2381), ('year', 13404), ('asa', 1064), ('patient', 8382), ('inn', 5848), ('bad', 1333), ('reput', 9225), ('visit', 12647), ('theeven', 11201), ('especi', 3582), ('someon', 10243), ('else', 3474), ('free', 4252), ('fromrisk', 4312), ('help', 5061), ('fumbl', 4339), ('knapsack', 6316), ('forhi', 4178), ('revolv', 9268), ('cough', 2605), ('sternli', 10523), ('tap', 10917), ('windowfram', 13161), ('hiswhip', 5389), ('hey', 5196), ('within', 13211), ('cri', 2679), ('granni', 4635), ('let', 6513), ('getwarm', 4456), ('with', 13185), ('hoars', 5400), ('black', 1678), ('dog', 3195), ('roll', 9326), ('like', 6554), ('ball', 1351), ('horse', 5462), ('sfeet', 9747), ('anoth', 854), ('white', 13063), ('ther', 11443), ('must', 7344), ('havebeen', 4928), ('dozen', 3258), ('look', 6685), ('see', 9629), ('biggestswung', 1649), ('whip', 13051), ('lash', 6428), ('longleggedpuppi', 6674), ('turn', 12240), ('sharp', 9775), ('muzzl', 7367), ('upward', 12485), ('set', 9721), ('shrill', 9892), ('piercinghowlyergunov', 8561), ('long', 6658), ('thehoarfrost', 11249), ('tree', 12150), ('near', 7466), ('glow', 4508), ('muffl', 7317), ('femalefigur', 3929), ('appear', 946), ('lantern', 6422), ('hands', 4841), ('warm', 12746), ('granny', 4636), ('said', 9412), ('thehospit', 11253), ('it', 6083), ('weather', 12878), ('god', 4520), ('preserv', 8780), ('usdon', 12493), ('afraid', 216), ('peopl', 8442), ('al', 317), ('didn', 3007), ('invit', 5983), ('strangers', 10598), ('saidth', 9425), ('figur', 3974), ('grimli', 4704), ('and', 514), ('knock', 6328), ('notlocked', 7703), ('yard', 13392), ('stop', 10567), ('steps', 10519), ('bid', 1645), ('labour', 6374), ('take',  ...
